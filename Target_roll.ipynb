# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib qt5
df = pd.read_csv('SCRLOG_02.csv', sep =';')
df.columns = df.columns.str.strip()

#count = df['wind_correct.heading'].isnull().sum()
#df=df.drop([0, count-1]).reset_index(drop=True)
#df = df[:-count].reset_index(drop=True)

df = df.drop_duplicates().reset_index(drop=True)
df=df[1:].reset_index(drop=True)

empty_numbers=df[df['wind_correct.heading'].isnull()].index.tolist()
df=df.dropna(axis=0, how='any')#не запустила в первом случае
df = df.apply(pd.to_numeric, errors='coerce')#учла наличие пустых значений
empty_numbers.append(len(df))

#df = df[['wrap_360(math.deg(current_orient:get_euler_yaw()))','calc_target.heading']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3546 entries, 0 to 3549
# Data columns (total 13 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   time_stamp(millis)                                  3545 non-null   float64
#  1   math.deg(current_orient:get_euler_pitch())          3545 non-null   float64
#  2   wrap_360(math.deg(current_orient:get_euler_yaw()))  3545 non-null   float64
#  3   calc_target.pitch                                   3545 non-null   float64
#  4   calc_target.heading                                 3545 non-null   float64
#  5   wind_correct.pitch                                  3545 non-null   float64
#  6   wind_correct.heading                                3545 non-null   float64
#  7   absolute_aim_orientation.pitch                      3545 non-null   float64
#  8   absolute_aim_orientation.bearing                    3545 non-null   float64
#  9   ahrs:airspeed_estimate()                            3545 non-null   float64
#  10  ctrl_roll_speed                                     3545 non-null   float64
#  11  ctrl_yawspd                                         3545 non-null   float64
#  12  ctrl_Roll                                           3545 non-null   float64
# dtypes: float64(13)
# memory usage: 387.8 KB

# %% [markdown]
# 'ctrl_yawspd' в радианы
# умножить ahrs:airspeed_estimate()
# /9.806565
# от результата арктангенс
# результат в градусы
# график - таргкт ролл
#
# наложить ctrl_Roll

# %%
import numpy as np

# %%
new_roll['target_roll'] = np.degrees(np.arctan((np.radians(df['ctrl_yawspd'])*df['ahrs:airspeed_estimate()'])/9.806565))
new_roll
df['target_roll'] = new_roll['target_roll']
df
# Out:
#       time_stamp(millis)  math.deg(current_orient:get_euler_pitch())  \
# 0               496447.0                                   -2.320240
# 1               496455.0                                   -2.299709
# 2               496477.0                                   -2.314059
# 3               496501.0                                   -2.326371
# 4               496517.0                                   -2.329852
# ...                  ...                                         ...
# 3545           1017321.0                                   10.353610
# 3546           1017344.0                                   10.324360
# 3547           1017363.0                                   10.282980
# 3548           1017385.0                                   10.240430
# 3549           1017404.0                                   10.192990
#
#       wrap_360(math.deg(current_orient:get_euler_yaw()))  calc_target.pitch  \
# 0                                              253.8388            1.779521
# 1                                              253.9931            1.779521
# 2                                              254.1311            1.779521
# 3                                              254.2680            1.841488
# 4                                              254.3796            1.841488
# ...                                                 ...                 ...
# 3545                                           344.5722            9.579032
# 3546                                           344.6370            9.579032
# 3547                                           344.6926           10.114480
# 3548                                           344.7438            9.836687
# 3549                                           344.7961            9.529643
#
#       calc_target.heading  wind_correct.pitch  wind_correct.heading  \
# 0                247.9940           -10.50000              0.000000
# 1                247.9940           -10.50000              0.000000
# 2                247.9940           -10.50000              0.000000
# 3                247.8018           -10.50000             -0.064054
# 4                247.8018           -10.50000             -0.064054
# ...                   ...                 ...                   ...
# 3545             338.8967           -11.03014              5.491708
# 3546             338.8967           -11.03014              5.491708
# 3547             339.9531           -10.67318              5.843831
# 3548             339.9850           -10.85837              5.854473
# 3549             340.0076           -11.06307              5.862014
#
#       absolute_aim_orientation.pitch  absolute_aim_orientation.bearing  \
# 0                          -8.720479                          247.9940
# 1                          -8.720479                          247.9940
# 2                          -8.720479                          247.9940
# 3                          -8.658512                          247.8659
# 4                          -8.658512                          247.8659
# ...                              ...                               ...
# 3545                       -1.451109                          333.4050
# 3546                       -1.451109                          333.4050
# 3547                       -0.558695                          334.1093
# 3548                       -1.021685                          334.1306
# 3549                       -1.533425                          334.1456
#
#       ahrs:airspeed_estimate()  ctrl_roll_speed  ctrl_yawspd  ctrl_Roll  \
# 0                     27.61156        -8.270626    -2.934068  -8.204677
# 1                     27.61156       -12.502920    -3.022033  -8.447158
# 2                     27.61156       -13.782780    -3.103906  -8.672572
# 3                     27.61156       -15.515690    -3.284598  -9.169095
# 4                     27.56793       -16.653120    -3.350911  -9.336455
# ...                        ...              ...          ...        ...
# 3545                  23.39026       -10.364920    -3.806753  -9.004844
# 3546                  23.39026       -10.284100    -3.852372  -9.110957
# 3547                  23.39026        -8.734420    -3.360941  -7.964692
# 3548                  23.39026        -7.858074    -3.381070  -8.011773
# 3549                  23.39301        -7.613365    -3.405495  -8.069826
#
#       target_roll
# 0       -8.204675
# 1       -8.447158
# 2       -8.672573
# 3       -9.169096
# 4       -9.336458
# ...           ...
# 3545    -9.004846
# 3546    -9.110958
# 3547    -7.964691
# 3548    -8.011775
# 3549    -8.069829
#
# [3546 rows x 14 columns]

# %%
df.plot(x="time_stamp(millis)",y=['target_roll','ctrl_Roll'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
